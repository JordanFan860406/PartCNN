# %%
import os

# %%
parts = os.listdir('Parts')

# %%
parts
# Out:
# ['10_bf5a8bbca38d4c97.jpg',
#  '10_dc05dcefc570d755.jpg',
#  '11_4b581c074ee14f99.jpg',
#  '11_9e113f0426d60aaf.jpg',
#  '12_4a3f4936e9e233cb.jpg',
#  '12_4b581c074ee14f99.jpg',
#  '12_9e113f0426d60aaf.jpg',
#  '12_bf5a8bbca38d4c97.jpg',
#  '13_9e113f0426d60aaf.jpg',
#  '13_bf5a8bbca38d4c97.jpg',
#  '14_9e113f0426d60aaf.jpg',
#  '14_bf5a8bbca38d4c97.jpg',
#  '15_9e113f0426d60aaf.jpg',
#  '15_dc05dcefc570d755.jpg',
#  '16_79e3e7a38ca4a32d.jpg',
#  '16_dc05dcefc570d755.jpg',
#  '16_dea27fa62416fbb4.jpg',
#  '17_4a3f4936e9e233cb.jpg',
#  '17_531f3c05dde112dd.jpg',
#  '17_9e113f0426d60aaf.jpg',
#  '1_00867630c33e0500.jpg',
#  '1_04792ff56b0eb66a.jpg',
#  '1_08438c38f7c796c5.jpg',
#  '1_0b43c30617054b36.jpg',
#  '1_123c2b3ad52add2a.jpg',
#  '1_193fdd653fccfb7a.jpg',
#  '1_1db3658f151852ca.jpg',
#  '1_21659114da515185.jpg',
#  '1_263a918e3149db16.jpg',
#  '1_27602c3c7474f0f4.jpg',
#  '1_2a173ad9fd450f30.jpg',
#  '1_2c7cf4b6aebf76d5.jpg',
#  '1_2cf71a0f24e2f91e.jpg',
# ...

# %%
crop = os.listdir('Crop')

# %%
crop
# Out:
# ['.DS_Store',
#  '100_f82416a7690d3925.jpg',
#  '101_f82416a7690d3925.jpg',
#  '102_f82416a7690d3925.jpg',
#  '103_f82416a7690d3925.jpg',
#  '104_f82416a7690d3925.jpg',
#  '105_f82416a7690d3925.jpg',
#  '106_f82416a7690d3925.jpg',
#  '107_f82416a7690d3925.jpg',
#  '108_f82416a7690d3925.jpg',
#  '109_f82416a7690d3925.jpg',
#  '10_1eca8923924cd689.jpg',
#  '10_24f0be601c5ce347.jpg',
#  '10_27602c3c7474f0f4.jpg',
#  '10_2b587e2f6dc2e70c.jpg',
#  '10_2e4c2bbeebdd3379.jpg',
#  '10_33a0cdc87728fe26.jpg',
#  '10_36384f7b1ccb6d69.jpg',
#  '10_386ce429b126cf61.jpg',
#  '10_3a0add8d7b586daa.jpg',
#  '10_3fc9cd9eb54220a6.jpg',
#  '10_42d29a0569e97da4.jpg',
#  '10_477ac161d854a754.jpg',
#  '10_4a3f4936e9e233cb.jpg',
#  '10_4b581c074ee14f99.jpg',
#  '10_4ba00b9932827478.jpg',
#  '10_531f3c05dde112dd.jpg',
#  '10_5b53afb03864bf8b.jpg',
#  '10_5d5c557141283747.jpg',
#  '10_70f69c2d22d5c2b2.jpg',
#  '10_79e3e7a38ca4a32d.jpg',
#  '10_8693e56cd8b97ff8.jpg',
#  '10_8cec179024855f94.jpg',
# ...

# %%
with open("part_labels.csv", "w", encoding="utf-8") as W:
    for file in parts:
        W.write(file+',1'+"\n")

# %%
with open("crop_labels.csv", "w", encoding="utf-8") as W:
    for file in crop:
        W.write(file+',0'+"\n")
